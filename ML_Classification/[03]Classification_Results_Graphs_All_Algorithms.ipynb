# %% [markdown]
# # Compare Learning Algorithms Scores - Graph view
# Graph view of all available classifiers in Pycaret library in manner of Browser, Operation-System and Application of Encrypted Inernet Network Traffic Samples.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
score_parameters = ['Accuracy', 'AUC', 'Recall', 'Prec', 'F1', 'Kappa', 'MCC']

# %%
algorithms_list = ['Extreme Gradient Boosting', 'Extra Trees Classifier', 'Random Forest Classifier',
'Light Gradient Boosting Machine', 'Decision Tree Classifier', 'Linear Discriminant Analysis',
'Ridge Classifier', 'Quadratic Discriminant Analysis', 'K Neighbors Classifier',
'Logistic Regression', 'Naive Bayes', 'SVM - Linear Kernel']

# %% [markdown]
# # Using All Features

# %%
full_features_scores = [[0.9796,0.0000,0.8955,0.9791,0.9787,0.9761,0.9761],
                           [0.9789,0.0000,0.9176,0.9794,0.9785,0.9753,0.9753],
                           [0.9735,0.0000,0.8799,0.9732,0.9723,0.9690,0.9691],
                           [0.9403,0.0000,0.8133,0.9730,0.9537,0.9311,0.9326],
                           [0.9385,0.0000,0.8027,0.9549,0.9421,0.9281,0.9288],
                           [0.8415,0.0000,0.6396,0.8567,0.8339,0.8134,0.8148],
                           [0.7958,0.0000,0.4320,0.7867,0.7522,0.7577,0.7613],
                           [0.7901,0.0000,0.5497,0.8770,0.7958,0.7564,0.7645],
                           [0.7743,0.0000,0.5159,0.7647,0.7656,0.7355,0.7358],
                           [0.4364,0.0000,0.1146,0.3419,0.3329,0.2390,0.2865],
                           [0.0508,0.0000,0.0700,0.4240,0.0447,0.0267,0.0649],
                           [0.0485,0.0000,0.0270,0.1053,0.0550,-0.0551,-0.0613]]

# %%
graph_map = {}
for i in algorithms_list:
    graph_map[i] = []

for i in range(0,len(full_features_scores)):
    current_algorithm = algorithms_list[i]
    graph_map[current_algorithm] = full_features_scores[i]

# %%
df = pd.DataFrame(graph_map, index=score_parameters)
ax = df.plot.bar(rot=0, figsize=(18,8), width=1)
ax.legend(loc='center left', bbox_to_anchor=(1, 1))

# %% [markdown]
# # Removed SSL Features

# %%
without_ssl_features = [[0.9808,0.0000,0.9061,0.9804,0.9800,0.9776,0.9776],
                            [0.9792,0.0000,0.8965,0.9788,0.9784,0.9756,0.9756],
                            [0.9731,0.0000,0.8703,0.9722,0.9717,0.9686,0.9686],
                            [0.9380,0.0000,0.8085,0.9553,0.9421,0.9276,0.9282],
                            [0.9362,0.0000,0.7990,0.9697,0.9493,0.9261,0.9277],
                            [0.8574,0.0000,0.5833,0.8790,0.8520,0.8330,0.8351],
                            [0.8404,0.0000,0.6443,0.8556,0.8337,0.8122,0.8136],
                            [0.7984,0.0000,0.4373,0.7968,0.7569,0.7607,0.7643],
                            [0.7752,0.0000,0.4952,0.7658,0.7666,0.7366,0.7369],
                            [0.4475,0.0000,0.1240,0.3565,0.3459,0.2630,0.3039],
                            [0.0528,0.0000,0.0233,0.1112,0.0538,-0.0555,-0.0643],
                            [0.0489,0.0000,0.0641,0.3965,0.0409,0.0246,0.0598]]

# %%
graph_map = {}
for i in algorithms_list:
    graph_map[i] = []

for i in range(0,len(without_ssl_features)):
    current_algorithm = algorithms_list[i]
    graph_map[current_algorithm] = without_ssl_features[i]

# %%
df = pd.DataFrame(graph_map, index=score_parameters)
ax = df.plot.bar(rot=0, figsize=(18,8), width=1)
ax.legend(loc='center left', bbox_to_anchor=(1, 1))

# %% [markdown]
# # Removed TCP Features

# %%
without_tcp_features = [[0.9812,0.0000,0.9138,0.9808,0.9806,0.9780,0.9780],
                        [0.9812,0.0000,0.8999,0.9802,0.9802,0.9780,0.9780],
                        [0.9743,0.0000,0.8703,0.9730,0.9728,0.9699,0.9700],
                        [0.9596,0.0000,0.8177,0.9723,0.9645,0.9528,0.9530],
                        [0.9395,0.0000,0.8085,0.9541,0.9426,0.9293,0.9298],
                        [0.8430,0.0000,0.6382,0.8531,0.8369,0.8150,0.8162],
                        [0.7966,0.0000,0.4339,0.7924,0.7546,0.7587,0.7624],
                        [0.7937,0.0000,0.5673,0.8761,0.7986,0.7603,0.7676],
                        [0.7752,0.0000,0.5071,0.7674,0.7674,0.7369,0.7371],
                        [0.4325,0.0000,0.1068,0.3264,0.3316,0.2464,0.2825],
                        [0.0819,0.0000,0.0345,0.1418,0.0812,-0.0426,-0.0512],
                        [0.0494,0.0000,0.0640,0.4675,0.0418,0.0256,0.0614]]

# %%
graph_map = {}
for i in algorithms_list:
    graph_map[i] = []

for i in range(0,len(without_ssl_features)):
    current_algorithm = algorithms_list[i]
    graph_map[current_algorithm] = without_tcp_features[i]

# %%
df = pd.DataFrame(graph_map, index=score_parameters)
ax = df.plot.bar(rot=0, figsize=(18,8), width=1)
ax.legend(loc='center left', bbox_to_anchor=(1, 1))

# %% [markdown]
# # Removed Both TCP and SSL Features

# %%
without_both_features = [[0.9796,0.0000,0.8955,0.9791,0.9787,0.9761,0.9761],
                                   [0.9789,0.0000,0.9176,0.9794,0.9785,0.9753,0.9753],
                                   [0.9735,0.0000,0.8799,0.9732,0.9723,0.9690,0.9691],
                                   [0.9403,0.0000,0.8133,0.9730,0.9537,0.9311,0.9326],
                                   [0.9385,0.0000,0.8027,0.9549,0.9421,0.9281,0.9288],
                                   [0.8415,0.0000,0.6396,0.8567,0.8339,0.8134,0.8148],
                                   [0.7958,0.0000,0.4320,0.7867,0.7522,0.7577,0.7613],
                                   [0.7901,0.0000,0.5497,0.8770,0.7958,0.7564,0.7645],
                                   [0.7743,0.0000,0.5159,0.7647,0.7656,0.7355,0.7358],
                                   [0.4364,0.0000,0.1146,0.3419,0.3329,0.2390,0.2865],
                                   [0.0508,0.0000,0.0700,0.4240,0.0447,0.0267,0.0649],
                                   [0.0485,0.0000,0.0270,0.1053,0.0550,-0.0551,-0.0613]]

# %%
graph_map = {}
for i in algorithms_list:
    graph_map[i] = []

for i in range(0,len(without_ssl_features)):
    current_algorithm = algorithms_list[i]
    graph_map[current_algorithm] = without_both_features[i]

# %%
df = pd.DataFrame(graph_map, index=score_parameters)
ax = df.plot.bar(rot=0, figsize=(18,8), width=1)
ax.legend(loc='center left', bbox_to_anchor=(1, 1))
